# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Bidirectional
from keras.callbacks import EarlyStopping
import yfinance as yf
from keras.models import load_model

# %%
ticker = 'AAPL'
data = yf.download(ticker, start='2010-01-01', end='2024-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
print(data.head())
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-01-04  7.622500  7.660714  7.585000  7.643214   6.447412  493729600
# 2010-01-05  7.664286  7.699643  7.616071  7.656429   6.458560  601904800
# 2010-01-06  7.656429  7.686786  7.526786  7.534643   6.355826  552160000
# 2010-01-07  7.562500  7.571429  7.466071  7.520714   6.344078  477131200
# 2010-01-08  7.510714  7.571429  7.466429  7.570714   6.386255  447610800

# %%
# Using only the 'Close' column
print(data[['Close']].values)
# Out:
# [[  7.64321423]
#  [  7.65642881]
#  [  7.53464317]
#  ...
#  [193.1499939 ]
#  [193.58000183]
#  [192.52999878]]

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# %%
train_size = int(len(scaled_data) * 0.8)
train_data = scaled_data[:train_size]
test_data = scaled_data[train_size:]

# %%
def create_dataset(data, time_step=1):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        a = data[i:(i + time_step), 0]
        X.append(a)
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)

# %%
time_step = 60
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
# Reshaping for LSTM
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# Building the model
model = Sequential()
model.add(Bidirectional(LSTM(units=50, return_sequences=True), input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(units=50, return_sequences=False)))
model.add(Dropout(0.2))
model.add(Dense(units=25))
model.add(Dense(units=1))

# %%
# Compiling the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Defining early stopping
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

# %%
# Training the model
model.fit(X_train, y_train, batch_size=32, epochs=100, validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 87/87 [==============================] - 33s 139ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 2/100
# 87/87 [==============================] - 7s 84ms/step - loss: 4.5692e-04 - val_loss: 0.0023
# Epoch 3/100
# 87/87 [==============================] - 8s 91ms/step - loss: 4.4902e-04 - val_loss: 7.6199e-04
# Epoch 4/100
# 87/87 [==============================] - 8s 88ms/step - loss: 3.3794e-04 - val_loss: 8.6956e-04
# Epoch 5/100
# 87/87 [==============================] - 7s 85ms/step - loss: 3.5053e-04 - val_loss: 7.0547e-04
# Epoch 6/100
# 87/87 [==============================] - 8s 90ms/step - loss: 2.9200e-04 - val_loss: 0.0033
# Epoch 7/100
# 87/87 [==============================] - 8s 92ms/step - loss: 2.4438e-04 - val_loss: 6.4204e-04
# Epoch 8/100
# 87/87 [==============================] - 8s 95ms/step - loss: 2.2940e-04 - val_loss: 0.0010
# Epoch 9/100
# 87/87 [==============================] - 8s 93ms/step - loss: 2.3801e-04 - val_loss: 5.4644e-04
# Epoch 10/100
# 87/87 [==============================] - 7s 86ms/step - loss: 2.7513e-04 - val_loss: 0.0011
# Epoch 11/100
# 87/87 [==============================] - 8s 91ms/step - loss: 2.4663e-04 - val_loss: 5.4217e-04
# Epoch 12/100
# 87/87 [==============================] - 7s 86ms/step - loss: 2.7762e-04 - val_loss: 0.0014
# Epoch 13/100
# 87/87 [==============================] - 8s 91ms/step - loss: 2.9519e-04 - val_loss: 0.0069
# Epoch 14/100
# 87/87 [==============================] - 8s 89ms/step - loss: 2.9977e-04 - val_loss: 0.0019
# Epoch 15/100
# 87/87 [==============================] - 8s 97ms/step - loss: 2.3552e-04 - val_loss: 6.6234e-04
# Epoch 16/100
# 87/87 [==============================] - 9s 99ms/step - loss: 2.1146e-04 - val_loss: 0.0012
# Epoch 17/100
# 87/87 [==============================] - 9s 102ms/step - loss: 2.2744e-04 - val_loss: 0.0024
# Epoch 18/100
# 87/87 [==============================] - 8s 93ms/step - loss: 1.9174e-04 - val_loss: 0.0024
# Epoch 19/100
# 87/87 [==============================] - 7s 86ms/step - loss: 2.1948e-04 - val_loss: 0.0012
# Epoch 20/100
# 87/87 [==============================] - 7s 85ms/step - loss: 2.5798e-04 - val_loss: 9.2030e-04
# Epoch 21/100
# 87/87 [==============================] - 7s 84ms/step - loss: 2.0829e-04 - val_loss: 4.5887e-04
# Epoch 22/100
# 87/87 [==============================] - 8s 89ms/step - loss: 2.4135e-04 - val_loss: 4.3798e-04
# Epoch 23/100
# 87/87 [==============================] - 7s 85ms/step - loss: 2.0380e-04 - val_loss: 4.3570e-04
# Epoch 24/100
# 87/87 [==============================] - 7s 80ms/step - loss: 1.8381e-04 - val_loss: 9.7264e-04
# Epoch 25/100
# 87/87 [==============================] - 7s 86ms/step - loss: 2.4379e-04 - val_loss: 4.7068e-04
# Epoch 26/100
# 87/87 [==============================] - 7s 84ms/step - loss: 2.2769e-04 - val_loss: 4.3336e-04
# Epoch 27/100
# 87/87 [==============================] - 7s 83ms/step - loss: 2.2116e-04 - val_loss: 0.0013
# Epoch 28/100
# 87/87 [==============================] - 8s 88ms/step - loss: 2.2607e-04 - val_loss: 9.4636e-04
# Epoch 29/100
# 87/87 [==============================] - 8s 90ms/step - loss: 2.3101e-04 - val_loss: 4.5072e-04
# Epoch 30/100
# 87/87 [==============================] - 7s 77ms/step - loss: 2.0099e-04 - val_loss: 0.0011
# Epoch 31/100
# 87/87 [==============================] - 7s 76ms/step - loss: 2.0835e-04 - val_loss: 3.9784e-04
# Epoch 32/100
# 87/87 [==============================] - 6s 74ms/step - loss: 1.9062e-04 - val_loss: 9.1298e-04
# Epoch 33/100
# 87/87 [==============================] - 7s 79ms/step - loss: 2.0429e-04 - val_loss: 3.8965e-04
# Epoch 34/100
# 87/87 [==============================] - 8s 93ms/step - loss: 1.9549e-04 - val_loss: 0.0016
# Epoch 35/100
# 87/87 [==============================] - 7s 77ms/step - loss: 3.0264e-04 - val_loss: 4.4085e-04
# Epoch 36/100
# 87/87 [==============================] - 6s 74ms/step - loss: 2.7364e-04 - val_loss: 0.0017
# Epoch 37/100
# 87/87 [==============================] - 6s 73ms/step - loss: 1.7998e-04 - val_loss: 4.7501e-04
# Epoch 38/100
# 87/87 [==============================] - 7s 78ms/step - loss: 1.8963e-04 - val_loss: 0.0017
# Epoch 39/100
# 87/87 [==============================] - 8s 91ms/step - loss: 1.8631e-04 - val_loss: 4.3343e-04
# Epoch 40/100
# 87/87 [==============================] - 7s 83ms/step - loss: 2.2243e-04 - val_loss: 9.6959e-04
# Epoch 41/100
# 87/87 [==============================] - 7s 77ms/step - loss: 2.1595e-04 - val_loss: 5.7902e-04
# Epoch 42/100
# 87/87 [==============================] - 6s 73ms/step - loss: 1.9182e-04 - val_loss: 0.0014
# Epoch 43/100
# 87/87 [==============================] - 7s 78ms/step - loss: 1.8877e-04 - val_loss: 5.2030e-04

# %%
# Saving the model to .h5
model.save('BiLSTM_model.h5')

# %%
# Predicting and inverse transforming
predictions = model.predict(X_test)

# Create an array of zeros with the same number of columns as the original data
predictions_extended = np.zeros((predictions.shape[0], scaled_data.shape[1]))

# Replace the 'Close' column with the predictions
predictions_extended[:, 3] = predictions.flatten()  # Assuming 'Close' is the 4th column (index 3)

# Inverse transform the extended predictions
predictions = scaler.inverse_transform(predictions_extended)[:, 3]  # Extract the 'Close' column
# Out:
# 21/21 [==============================] - 5s 24ms/step

# %%
# Calculating RMSE
y_test_extended = np.zeros((y_test.shape[0], scaled_data.shape[1]))
y_test_extended[:, 3] = y_test  # Assuming 'Close' is the 4th column (index 3)

y_test_inverse = scaler.inverse_transform(y_test_extended)[:, 3]  # Extract the 'Close' column

rmse = np.sqrt(np.mean((predictions - y_test_inverse)**2))
print(f'Root Mean Squared Error: {rmse}')
# Out:
# Root Mean Squared Error: 4.362451772276482

# %%
# Plotting the results
train = data[:train_size]
valid = data[train_size:train_size + len(predictions)].copy()
valid['Close'] = predictions.flatten()  # Update valid with predictions

plt.figure(figsize=(16,8))
plt.title('Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Close Price USD')
plt.plot(train['Close'], label='Training Data')
plt.plot(valid['Close'], label='Predictions')
plt.legend()
plt.show()
