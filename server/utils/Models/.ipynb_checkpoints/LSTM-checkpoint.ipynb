# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.layers import Bidirectional
import yfinance as yf

# %%
ticker = 'AAPL'
data = yf.download(ticker, start='2010-01-01', end='2024-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
print(data.head())
# Out:
# Price                     Adj Close     Close      High       Low      Open  \
# Ticker                         AAPL      AAPL      AAPL      AAPL      AAPL
# Date
# 2010-01-04 00:00:00+00:00  6.454505  7.643214  7.660714  7.585000  7.622500
# 2010-01-05 00:00:00+00:00  6.465663  7.656429  7.699643  7.616071  7.664286
# 2010-01-06 00:00:00+00:00  6.362819  7.534643  7.686786  7.526786  7.656429
# 2010-01-07 00:00:00+00:00  6.351056  7.520714  7.571429  7.466071  7.562500
# 2010-01-08 00:00:00+00:00  6.393281  7.570714  7.571429  7.466429  7.510714
#
# Price                         Volume
# Ticker                          AAPL
# Date
# 2010-01-04 00:00:00+00:00  493729600
# 2010-01-05 00:00:00+00:00  601904800
# 2010-01-06 00:00:00+00:00  552160000
# 2010-01-07 00:00:00+00:00  477131200
# 2010-01-08 00:00:00+00:00  447610800

# %%
data = data[['Close']]
data = data.values

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# %%
train_size = int(len(scaled_data) * 0.8)
train_data = scaled_data[:train_size]
test_data = scaled_data[train_size:]

# %%
def create_dataset(data, time_step=1):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        a = data[i:(i + time_step), 0]
        X.append(a)
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)

# %%
time_step = 60
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
model = Sequential()
model.add(Bidirectional(LSTM(units=50, return_sequences=True), input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(units=50, return_sequences=False)))
model.add(Dropout(0.2))
model.add(Dense(units=25))
model.add(Dense(units=1))
# Out:
# c:\Users\DESKTOP\anaconda3\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10)
model.fit(X_train, y_train, batch_size=32, epochs=100, validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.6947e-04 - val_loss: 7.2895e-04
# Epoch 2/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 2.1487e-04 - val_loss: 0.0022
# Epoch 3/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.6808e-04 - val_loss: 3.3361e-04
# Epoch 4/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.9091e-04 - val_loss: 5.6554e-04
# Epoch 5/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.6432e-04 - val_loss: 4.3194e-04
# Epoch 6/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.6267e-04 - val_loss: 6.9331e-04
# Epoch 7/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.3156e-04 - val_loss: 5.6291e-04
# Epoch 8/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 2.1017e-04 - val_loss: 0.0037
# Epoch 9/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 2.3799e-04 - val_loss: 0.0011
# Epoch 10/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.9975e-04 - val_loss: 6.3530e-04
# Epoch 11/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.8107e-04 - val_loss: 4.2030e-04
# Epoch 12/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 2.5842e-04 - val_loss: 0.0011
# Epoch 13/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.9674e-04 - val_loss: 5.3293e-04

# %%
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step

# %%
rmse = np.sqrt(np.mean((predictions - scaler.inverse_transform(y_test.reshape(-1, 1)))**2))
print(f'Root Mean Squared Error: {rmse}')
# Out:
# Root Mean Squared Error: 4.492165573746199

# %%
train = data[:train_size]
valid = data[train_size:train_size + len(predictions)]
valid[:, 0] = predictions.flatten()  # Update valid with predictions

plt.figure(figsize=(16,8))
plt.title('Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Close Price USD')
plt.plot(train, label='Training Data')
plt.plot(valid, label='Predictions')
plt.legend()
plt.show()
